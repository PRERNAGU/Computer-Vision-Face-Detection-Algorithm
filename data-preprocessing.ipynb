# %%
import os
import json
import glob
import numpy as np 
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
import os, sys
import pandas as pd
import numpy as np
import cv2

#raw folder contains sub-folders with IDs and respective individual images and vedios 
# from each sub-folder extract the folder or Id name, and complete path of image/vedio and store in variable g, as a tuple;
#eg) [(ID, filepath)]
file_path = (r'C:\Users\Prerna Prakash Gupta\Desktop\raw')
g=[]
for root, dirs, files in os.walk(file_path):    
    for name in files: 
        s=root[-2:]
        v=os.path.join(root, name)
        l=(s,v)
        g.append(l)
g


prerna=[]
for i in g:
    if i[1].endswith('.JPG'):
        prerna.append([(i[0], i[1])])

   

prerna
# Out:
# <CascadeClassifier 0000019C96A68F50>
# [[('01', 'C:\\Users\\Prerna Prakash Gupta\\Desktop\\raw\\01\\IMG_6855.JPG')],
#  [('01', 'C:\\Users\\Prerna Prakash Gupta\\Desktop\\raw\\01\\IMG_6856.JPG')],
#  [('01', 'C:\\Users\\Prerna Prakash Gupta\\Desktop\\raw\\01\\IMG_6857.JPG')],
#  [('01', 'C:\\Users\\Prerna Prakash Gupta\\Desktop\\raw\\01\\IMG_6858.JPG')],
#  [('01', 'C:\\Users\\Prerna Prakash Gupta\\Desktop\\raw\\01\\IMG_6859.JPG')],
#  [('01', 'C:\\Users\\Prerna Prakash Gupta\\Desktop\\raw\\01\\IMG_6860.JPG')],
#  [('01', 'C:\\Users\\Prerna Prakash Gupta\\Desktop\\raw\\01\\IMG_6861.JPG')],
#  [('01', 'C:\\Users\\Prerna Prakash Gupta\\Desktop\\raw\\01\\IMG_6862.JPG')],
#  [('02', 'C:\\Users\\Prerna Prakash Gupta\\Desktop\\raw\\02\\IMG_2594.JPG')],
#  [('02', 'C:\\Users\\Prerna Prakash Gupta\\Desktop\\raw\\02\\IMG_2595.JPG')],
#  [('02', 'C:\\Users\\Prerna Prakash Gupta\\Desktop\\raw\\02\\IMG_2596.JPG')],
#  [('02', 'C:\\Users\\Prerna Prakash Gupta\\Desktop\\raw\\02\\IMG_2597.JPG')],
# ...

# %%
#Extract HarrasCascase Haar Cascade classifier, based on the Haar Wavelet technique to analyse pixels in the image; cascade classifier is based on Viola Jones detection algorithm 

face_cascade = cv2.CascadeClassifier(r'C:\Users\Prerna Prakash Gupta\Anaconda3\Library\etc\haarcascades\haarcascade_frontalface_default.xml')
print(face_cascade)
#for .JPG files or images in g, extract faces and save them in list pererna consisting of ID names, and filepath of images

#create the face dectection function from individual images
def detect_face(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.5, minNeighbors=5)
    return faces


    
#change directory to where training data will be stires  
os.chdir(r'C:\\Users\\Prerna Prakash Gupta\\Desktop\\faces')    

#for each image in list prerna created above; extract indivual faces, and save them in directory 'face'; along with their ID name in image name
for img in range(len(prerna)):
    var_img = cv2.imread(prerna[img][0][1])
    face = detect_face(var_img)
    print(face)
    if (len(face) == 0):
        continue
    for(ex, ey, ew, eh) in face:
        crop_image = var_img[ey:ey+eh, ex:ex+ew] 
    cv2.imwrite(os.path.join(str(img)+prerna[img][0][0]+'.JPG'),crop_image)

# %%
#List g created which had indiviudal IDs and file paths; from list g extract, vedios (.mp4) format and store ID name and video path, as a tuple in list prerna1
#eg([[(ID, filepath.mp4)]])

import numpy as np
import cv2

print(face_cascade)
prerna1=[]
for i in g:
    if i[1].endswith('.mp4'):
        prerna1.append([(i[0], i[1])])

   

prerna1

# %%
#extract individual frames from videos
#upto 40-50 frames from individual videos created and saved in data folder, along with their ID name
#The ID number has been added in every image frame extracted from respective video

#brightness_4
# Read the video from specified path 
for i in range(len(prerna1)):
    cam = cv2.VideoCapture(prerna1[i][0][1])

    try: 

        # creating a folder named data 
        if not os.path.exists('data'): 
            os.makedirs('data') 

    # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of data') 

    # frame 
    currentframe = 0

    while(True): 

        # reading from frame 
        ret,frame = cam.read() 

        if ret: 
            # if video is still left continue creating images 
            name = './data/frame' + str(currentframe) +str(prerna1[i][0][0]) +'.jpg'
            print ('Creating...' + name) 

            # writing the extracted images 
            cv2.imwrite(name, frame) 

            # increasing counter so that it will 
            # show how many frames are created 
            currentframe += 1
        else: 
            break

    # Release all space and windows once done 
    cam.release() 
    cv2.destroyAllWindows()

# %%
#from vedio frames, after indivual frames were extracted in last section; faces were extracted from each frame and saved in a folder
def detect_face(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.5, minNeighbors=5)
    return faces

  
#extract face from each frame and save in a folder

for frame in range(len(gup)):
    var_img = cv2.imread(gup[frame][0][1])
    face = detect_face(var_img)
    print(face)
    if (len(face) == 0):
        continue
    for(ex, ey, ew, eh) in face:
        crop_image = var_img[ey:ey+eh, ex:ex+ew] 
    cv2.imwrite(os.path.join('ved'+str(frame)+gup[frame][0][0]+'.JPG'),crop_image)

# %%
#now we have a single folder consisting of extracted faces from all vedio frames and indivual image frame, and each extracted face
#consists of ID number in its name.
#create a list 'all'; containing filepaths of all face images 



file_path = (r'C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22')
all=[]
for root, dirs, files in os.walk(file_path):    
    for name in files: 
        v=os.path.join(root, name)
        print(v)
        all.append(v)

all
# Out:
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\10060.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\10278.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\10308.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\10510.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\10601.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\10616.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\10702.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\10716.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\10816.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\10904.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\10916.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\11016.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\1102.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\11106.JPG
# C:\Users\Prerna Prakash Gupta\Desktop\faces1\data22\11308.JPG
# ...

# %%
#create augmentation of training data; by applying rotation, noise (blur) and flipping of images in training data

import random
from scipy import ndarray
import skimage as sk
from skimage import transform
from skimage import util

def random_rotation(image_array: ndarray):
    # pick a random degree of rotation between 25% on the left and 25% on the right
    random_degree = random.uniform(-25, 25)
    return sk.transform.rotate(image_array, random_degree)

def random_noise(image_array: ndarray):
    # add random noise to the image
    return sk.util.random_noise(image_array)

def horizontal_flip(image_array: ndarray):
    # horizontal flip doesn't need skimage, it's easy as flipping the image array of pixels !
    return image_array[:, ::-1]

# %%
#in the following folder, the augmented images are saved
os.chdir(r'C:\\Users\\Prerna Prakash Gupta\\Desktop\\faces1\\augmented')

# dictionary of the transformations functions we defined earlier

available_transformations = {
    'rotate': random_rotation,
    'noise': random_noise,
    'horizontal_flip': horizontal_flip
}

#the augmentation functions are applied to all the images saved previously. It is applied on list 'all' which contains file-path
#of all faces extracted from video and individual images. Each image name is saved so as it contains the ID name in its name.
for i in all:
    image_to_transform = sk.io.imread(i)
    for key in available_transformations:
        transformed_image = available_transformations[key](image_to_transform)
        sk.io.imsave(i + 'aug'+'.JPG', transformed_image)

# %%
#Now we add faces from GROUP-IMAGES to the training data
#We create a list containing a file path of all images in the 'jpeg' folder containing group-images
import os, sys

import pandas as pd

file_path = (r'C:\Users\Prerna Prakash Gupta\Desktop\jpeg')
g1=[]
for root, dirs, files in os.walk(file_path): 
    for name in files:
        g1.append(root+'\\'+name)
g1
# Out:
# ['C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6819.JPG',
#  'C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6820.JPG',
#  'C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6822.JPG',
#  'C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6823.JPG',
#  'C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6825.JPG',
#  'C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6826.JPG',
#  'C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6827.JPG',
#  'C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6828.JPG',
#  'C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6829.JPG',
#  'C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6830.JPG',
#  'C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6831.JPG',
#  'C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6832.JPG',
#  'C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6833.JPG',
#  'C:\\Users\\Prerna Prakash Gupta\\Desktop\\jpeg\\IMG_6834.JPG',
# ...

# %%
#from each group image-as many faces as possible as detected and cropped and saved in a folder
#below we print out how many faces are detected from each image

face_cascade = cv2.CascadeClassifier(r'C:\Users\Prerna Prakash Gupta\Anaconda3\Library\etc\haarcascades\haarcascade_frontalface_default.xml')
  
os.chdir(r'C:\\Users\\Prerna Prakash Gupta\\Desktop\\faces1\\testdata')    

for i in g1:
    image =cv2.imread(i)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    haarcascade_frontalface_default.xml")
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=3, minSize=(30, 30))
    print("Found {0} Faces!".format(len(faces)))

    count=0
    for (ex, ey, ew, eh) in faces:
        crop_image = image[ey:ey+eh, ex:ex+ew] 
        count=count+1
        cv2.imwrite((str(i)+str(count)+'.JPG'),crop_image)  

#subsequently each face from each group image in the folder is manually visualised and saved in a folder containing respective ID name
# Out:
# Found 19 Faces!
# Found 17 Faces!
# Found 18 Faces!
# Found 23 Faces!
# Found 23 Faces!
# Found 19 Faces!
# Found 20 Faces!
# Found 20 Faces!
# Found 17 Faces!
# Found 14 Faces!
# Found 19 Faces!
# Found 17 Faces!
# Found 11 Faces!
# Found 13 Faces!
# Found 13 Faces!
# Found 11 Faces!
# Found 15 Faces!
# Found 18 Faces!
# Found 19 Faces!
# Found 31 Faces!
# Found 41 Faces!
# Found 31 Faces!
# Found 35 Faces!
# Found 34 Faces!
# Found 39 Faces!
# Found 31 Faces!
# Found 31 Faces!
# Found 22 Faces!
# Found 22 Faces!
# Found 13 Faces!
